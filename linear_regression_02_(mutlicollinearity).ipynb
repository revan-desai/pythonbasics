# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/pythonbasics/blob/main/linear_regression_02_(mutlicollinearity).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tita=sns.load_dataset('titanic')
tita=tita.drop(['sex','class','who','adult_male','embark_town','alone','embarked','alive','deck'],axis=1)
sns.heatmap(tita.corr(),annot=True)
# Out:
# <Axes: >
